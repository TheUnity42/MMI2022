# %%
import re
import socket
import pandas as pd
from pathlib import Path
#import keyboard

# %%
 

localIP     = "0.0.0.0"

localPort   = 6001

bufferSize  = 1600

 

msgFromServer       = "Hello UDP Client"

bytesToSend         = str.encode(msgFromServer)

 

# Create a datagram socket

UDPServerSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Bind to address and ip

UDPServerSocket.bind((localIP, localPort))
UDPServerSocket.setsockopt(socket.SOL_SOCKET, socket.SO_RCVBUF, 1024)
 

print("UDP server up and listening")

messageList=[] 

# Listen for incoming datagrams

while(True):
    adc0Label =0 



    bytesAddressPair = UDPServerSocket.recvfrom(bufferSize)

    message = bytesAddressPair[0].decode("utf-8")
    messageList.append(message + f"{adc0Label}")

    address = bytesAddressPair[1]

    clientMsg = "Message from Client:{}".format(message)
    clientIP  = "Client IP Address:{}".format(address)
    
    print(clientMsg)
    print(clientIP)

   

    # Sending a reply to client

    #UDPServerSocket.sendto(bytesToSend, address)
# Out:
# UDP server up and listening
# Message from Client:(18.000000,252141589,1.509814,1.485644,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252146606,1.530762,1.492895,1.513037,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(16.000000,252151623,1.528345,1.492090,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(15.000000,252156640,1.511426,1.488867,1.504175,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(14.000000,252161657,1.525122,1.460669,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(13.000000,252166674,1.531567,1.496118,1.507397,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(12.000000,252171691,1.516260,1.487256,1.499341,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(11.000000,252176707,1.519482,1.499341,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(10.000000,252181723,1.535596,1.474365,1.506592,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(9.000000,252186747,1.519482,1.489673,1.501758,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(8.000000,252191765,1.512231,1.495312,1.505786,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(7.000000,252196781,1.532373,1.518677,1.510620,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(6.000000,252201797,1.527539,1.496924,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(5.000000,252206813,1.513037,1.492090,1.498535,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(4.000000,252211830,1.524316,1.500147,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(2.000000,252221862,1.515454,1.491284,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(2.000000,252226879,1.522705,1.492090,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(1.000000,252231895,1.533984,1.499341,1.511426,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(0.000000,252236930,1.511426,1.485644,1.498535,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(18.000000,252241958,1.514648,1.496118,1.497729,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252246974,1.529150,1.499341,1.508203,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(16.000000,252251990,1.525122,1.492895,1.504175,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(15.000000,252257006,1.515454,1.492090,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(14.000000,252262022,1.523511,1.484839,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(13.000000,252267038,1.528345,1.516260,1.509814,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(12.000000,252272054,1.512231,1.501758,1.501758,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(11.000000,252277071,1.519482,1.504980,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(9.000000,252287104,1.521094,1.484033,1.507397,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(8.000000,252292123,1.516260,1.488062,1.506592,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(7.000000,252297140,1.529956,1.503369,1.511426,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(6.000000,252302157,1.529150,1.492090,1.505786,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(5.000000,252307174,1.517065,1.521899,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(4.000000,252312190,1.527539,1.491284,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(3.000000,252317206,1.531567,1.504175,1.512231,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(2.000000,252322223,1.516260,1.509814,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(1.000000,252327239,1.522705,1.474365,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(0.000000,252332256,1.534790,1.499341,1.506592,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(0.000000,252337291,1.510620,1.488062,1.497729,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252342318,1.512231,1.484839,1.496924,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252347335,1.534790,1.497729,1.507397,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(16.000000,252352351,1.523511,1.501758,1.500147,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(15.000000,252357367,1.511426,1.497729,1.500952,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(14.000000,252362383,1.525122,1.496118,1.508203,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(13.000000,252367400,1.527539,1.492895,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(12.000000,252372416,1.515454,1.484839,1.499341,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(11.000000,252377433,1.522705,1.472754,1.504175,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(10.000000,252382449,1.531567,1.529956,1.510620,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(9.000000,252387475,1.515454,1.484839,1.504980,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(8.000000,252392495,1.515454,1.490479,1.499341,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(7.000000,252397511,1.534790,1.492895,1.511426,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(6.000000,252402527,1.521094,1.491284,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(5.000000,252407543,1.512231,1.463086,1.505786,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(3.000000,252417576,1.528345,1.492895,1.509814,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(2.000000,252422592,1.514648,1.484033,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(1.000000,252427608,1.521094,1.502563,1.509009,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(0.000000,252432635,1.531567,1.469531,1.508203,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(18.000000,252437668,1.516260,1.493701,1.498535,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252442690,1.513037,1.496118,1.501758,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(17.000000,252447706,1.531567,1.493701,1.508203,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(16.000000,252452724,1.524316,1.491284,1.503369,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(15.000000,252457741,1.516260,1.490479,1.504175,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(14.000000,252462758,1.528345,1.496118,1.507397,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(13.000000,252467774,1.529956,1.502563,1.508203,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(12.000000,252472790,1.509814,1.456641,1.499341,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(10.000000,252482823,1.530762,1.473559,1.509009,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(9.000000,252487841,1.517871,1.496924,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(8.000000,252492861,1.518677,1.492895,1.499341,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(6.000000,252502894,1.521899,1.490479,1.509009,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(5.000000,252507911,1.510620,1.495312,1.502563,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(4.000000,252512928,1.529150,1.504175,1.507397,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(3.000000,252517944,1.532373,1.467920,1.505786,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(2.000000,252522961,1.513037,1.492895,1.501758,0)
#
# Client IP Address:('10.42.0.245', 58852)
# Message from Client:(1.000000,
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W1sZmlsZQ%3D%3D?line=32'>33</a> while(True):
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a>     adc0Label =0
# ---> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a>     bytesAddressPair = UDPServerSocket.recvfrom(bufferSize)
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W1sZmlsZQ%3D%3D?line=39'>40</a>     message = bytesAddressPair[0].decode("utf-8")
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W1sZmlsZQ%3D%3D?line=40'>41</a>     messageList.append(message + f"{adc0Label}")
#
# KeyboardInterrupt:

# %%
print(type(message))

val = message.decode("utf-8")
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/talonh/Projects/MMI2022/udp/server.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> print(type(message))
# ----> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> val = message.decode("utf-8")
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
# print(type(val))
# print(val)
test=messageList

# %%
def decodeList(byteList):
    decoded=[]
    output=[]
    for row in byteList:
        
        decoded.append(row)

        
    
   
    
    for x, row in enumerate(decoded):
        
        row = re.sub(r'[) ( ]', '', str(row))
        decoded[x] = re.split(",", str(row))
        output.append(decoded[x])

    for r, values in enumerate(output):
        for c, pos in enumerate(values):
            output[r][c] = float(pos)
        
    #decoded = re.split(',', decoded)
    return output

# %%
temp = decodeList(test)
# print(temp[0])
# temp = test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/talonh/Projects/MMI2022/udp/server.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> temp = decodeList(test)
#
# /home/talonh/Projects/MMI2022/udp/server.ipynb Cell 6 in decodeList(byteList)
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> for r, values in enumerate(output):
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a>     for c, pos in enumerate(values):
# ---> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a>         output[r][c] = float(pos)
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> #decoded = re.split(',', decoded)
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> return output
#
# ValueError: could not convert string to float: '0\n0'

# %%
temp = decodeList(test)
print(len(temp))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/talonh/Projects/MMI2022/udp/server.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> temp = decodeList(test)
#       <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> print(len(temp))
#
# /home/talonh/Projects/MMI2022/udp/server.ipynb Cell 7 in decodeList(byteList)
#       <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> output=[]
#       <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> for row in byteList:
# ----> <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     decoded.append(row.decode('utf-8'))
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> for x, row in enumerate(decoded):
#      <a href='vscode-notebook-cell:/home/talonh/Projects/MMI2022/udp/server.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>     row = re.sub(r'[) ( ]', '', str(row))
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
df = pd.DataFrame(temp)
# df.columns = ["sample", "timeSinceboot", "ADC0", "ADC1", "ADC2"]
display(df)
# Out:
#                                                       0
# 0     (18.000000,252141589,1.509814,1.485644,1.50256...
# 1     (17.000000,252146606,1.530762,1.492895,1.51303...
# 2     (16.000000,252151623,1.528345,1.492090,1.50498...
# 3     (15.000000,252156640,1.511426,1.488867,1.50417...
# 4     (14.000000,252161657,1.525122,1.460669,1.50498...
# ...                                                 ...
# 5230  (4.000000,280616128,1.514648,1.489673,1.500147...
# 5231  (3.000000,280621144,1.536401,1.484839,1.507397...
# 5232  (2.000000,280626160,1.519482,1.496924,1.510620...
# 5233  (1.000000,280631176,1.513843,1.501758,1.505786...
# 5234  (0.000000,280636206,1.524316,1.488867,1.503369...
#
# [5235 rows x 1 columns]

# %%
path = Path("./data/output.csv")
df.to_csv(path)

# %% [markdown]
# # This cell exists to hold letter input so the cells are not broken while code is in use!!!
#
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
while True:
   
 if(keyboard.is_pressed('i')):

    
    print("hello")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_6667/297896486.py in <module>
#       1 while True:
#       2
# ----> 3  if(keyboard.is_pressed('i')):
#       4
#       5
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in is_pressed(hotkey)
#     408         is_pressed('ctrl+space') #-> True
#     409     """
# --> 410     _listener.start_if_necessary()
#     411
#     412     if _is_number(hotkey):
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_generic.py in start_if_necessary(self)
#      33         try:
#      34             if not self.listening:
# ---> 35                 self.init()
#      36
#      37                 self.listening = True
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in init(self)
#     194
#     195     def init(self):
# --> 196         _os_keyboard.init()
#     197
#     198         self.active_modifiers = set()
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixkeyboard.py in init()
#     111
#     112 def init():
# --> 113     build_device()
#     114     build_tables()
#     115
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixkeyboard.py in build_device()
#     107     global device
#     108     if device: return
# --> 109     ensure_root()
#     110     device = aggregate_devices('kbd')
#     111
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixcommon.py in ensure_root()
#     172 def ensure_root():
#     173     if os.geteuid() != 0:
# --> 174         raise ImportError('You must be root to use this library on linux.')
#
# ImportError: You must be root to use this library on linux.

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_6667/2435103061.py in <module>
#       1 import keyboard
#       2
# ----> 3 keyboard.press_and_release('shift+s, space')
#       4
#       5 keyboard.write('The quick brown fox jumps over the lazy dog.')
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in send(hotkey, do_press, do_release)
#     377     _listener.is_replaying = True
#     378
# --> 379     parsed = parse_hotkey(hotkey)
#     380     for step in parsed:
#     381         if do_press:
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in parse_hotkey(hotkey)
#     356     for step in _re.split(r',\s?', hotkey):
#     357         keys = _re.split(r'\s?\+\s?', step)
# --> 358         steps.append(tuple(key_to_scan_codes(key) for key in keys))
#     359     return tuple(steps)
#     360
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in <genexpr>(.0)
#     356     for step in _re.split(r',\s?', hotkey):
#     357         keys = _re.split(r'\s?\+\s?', step)
# --> 358         steps.append(tuple(key_to_scan_codes(key) for key in keys))
#     359     return tuple(steps)
#     360
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in key_to_scan_codes(key, error_if_missing)
#     309     normalized = normalize_name(key)
#     310     if normalized in sided_modifiers:
# --> 311         left_scan_codes = key_to_scan_codes('left ' + normalized, False)
#     312         right_scan_codes = key_to_scan_codes('right ' + normalized, False)
#     313         return left_scan_codes + tuple(c for c in right_scan_codes if c not in left_scan_codes)
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in key_to_scan_codes(key, error_if_missing)
#     315     try:
#     316         # Put items in ordered dict to remove duplicates.
# --> 317         t = tuple(_collections.OrderedDict((scan_code, True) for scan_code, modifier in _os_keyboard.map_name(normalized)))
#     318         e = None
#     319     except (KeyError, ValueError) as exception:
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py in <genexpr>(.0)
#     315     try:
#     316         # Put items in ordered dict to remove duplicates.
# --> 317         t = tuple(_collections.OrderedDict((scan_code, True) for scan_code, modifier in _os_keyboard.map_name(normalized)))
#     318         e = None
#     319     except (KeyError, ValueError) as exception:
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixkeyboard.py in map_name(name)
#     146
#     147 def map_name(name):
# --> 148     build_tables()
#     149     for entry in from_name[name]:
#     150         yield entry
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixkeyboard.py in build_tables()
#      62 def build_tables():
#      63     if to_name and from_name: return
# ---> 64     ensure_root()
#      65
#      66     modifiers_bits = {
#
# ~/anaconda3/lib/python3.9/site-packages/keyboard/_nixcommon.py in ensure_root()
#     172 def ensure_root():
#     173     if os.geteuid() != 0:
# --> 174         raise ImportError('You must be root to use this library on linux.')
#
# ImportError: You must be root to use this library on linux.
